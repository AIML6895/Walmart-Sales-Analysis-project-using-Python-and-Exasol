# %%
# !pip install pyexasol
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyexasol pandas matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyexasol
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pyexasol
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Connect to your running Exasol Docker instance
C = pyexasol.connect(
    dsn='127.0.0.1:8563',  # Docker maps this port to your host
    user='sys',
    password='exasol',
    schema='SYS'  # Use 'SYS' or any existing schema
)

# %%
import pyexasol
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

C = pyexasol.connect(
    dsn='127.0.0.1:8563',
    user='sys',
    password='exasol',
    schema='SYS'
)

# %%
import pyexasol
import pandas as pd

# %%
# Connect to the running Exasol DB container
C = pyexasol.connect(
    dsn='127.0.0.1:8563',
    user='sys',
    password='exasol',
    schema='SYS'
)

# %%
# Load your CSV file into a DataFrame
df = pd.read_csv("Walmart Sales Data.csv.csv")  # replace with your actual file name
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date      Time      Payment    cogs  gross margin percentage  \
# 0  2019-01-05  13:08:00      Ewallet  522.83                 4.761905
# 1  2019-03-08  10:29:00         Cash   76.40                 4.761905
# ...

# %%
df.tail(
)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total        Date      Time  Payment  \
# 995       40.35         1   2.0175    42.3675  2019-01-29  13:46:00  Ewallet
# 996       97.38        10  48.6900  1022.4900  2019-03-02  17:16:00  Ewallet
# 997       31.84         1   1.5920    33.4320  2019-02-09  13:22:00     Cash
# 998       65.82         1   3.2910    69.1110  2019-02-22  15:33:00     Cash
# 999       88.34         7  30.9190   649.2990  2019-02-18  13:28:00     Cash
#
# ...

# %%
# 🧩 Step 5: Optional – Check & Clean the DataFrame

# %%
df.info()
df.columns = [c.upper().replace(" ", "_") for c in df.columns]  # clean column names
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
# 🧩 Step 6: Upload the DataFrame into Exasol Table

# %%
# Step 1: Drop the table if it exists (to replace it)
C.execute("DROP TABLE IF EXISTS SALES_DATA")
# Out:
# <ExaStatement session_id=1833738724867244032 stmt_idx=1>

# %%
import pyexasol
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pyexasol

# Connect to Exasol running locally in Docker
conn = pyexasol.connect(
    dsn='127.0.0.1:8563',
    user='sys',
    password='exasol'
)

# Test query
print(conn.execute("SELECT 'Hello from Exasol!'").fetchall())
# Out:
# [('Hello from Exasol!',)]

# %%
# Verify Data Upload by Querying the Table

# %%
# Perform Basic Exploratory Data Analysis (EDA)

# %%
tables = conn.execute("SELECT TABLE_NAME FROM EXA_ALL_TABLES WHERE TABLE_SCHEMA = CURRENT_SCHEMA").fetchall()
print(tables)
# Out:
# []

# %%
query = """
SELECT CITY, SUM(TOTAL) AS TOTAL_SALES
FROM your_actual_table_name
GROUP BY CITY
ORDER BY TOTAL_SALES DESC
"""

# %%
all_tables = conn.execute("SELECT TABLE_SCHEMA, TABLE_NAME FROM EXA_ALL_TABLES").fetchall()
for row in all_tables:
    print(row)

# %%
query = """
SELECT EXTRACT(YEAR FROM "DATE") AS YEAR,
       EXTRACT(MONTH FROM "DATE") AS MONTH,
       SUM(TOTAL) AS MONTHLY_SALES
FROM SALES_DATA
GROUP BY YEAR, MONTH
ORDER BY YEAR, MONTH
"""

# %%
import pyexasol

# Only run this once (make sure your Exasol container is running)
conn = pyexasol.connect(dsn='127.0.0.1:8563', user='sys', password='exasol')

# %%
tables = conn.execute("SELECT TABLE_SCHEMA, TABLE_NAME FROM SYS.EXA_ALL_TABLES WHERE TABLE_NAME LIKE '%SALES%'").fetchall()
print(tables)
# Out:
# []
